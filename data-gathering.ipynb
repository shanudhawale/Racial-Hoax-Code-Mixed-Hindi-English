# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install youtube-comment-downloader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# %cd '/content/drive/MyDrive/Thesis2'
# Out:
# /content/drive/MyDrive/Thesis2

# %%
from itertools import islice
from youtube_comment_downloader import *
downloader = YoutubeCommentDownloader()
comments = downloader.get_comments_from_url('https://www.youtube.com/watch?v=2pB7bRjpwQc')
# print(len(list(comments)))
for comment in islice(comments, 10):
    print(comment)
# Out:
# {'cid': 'UgzNgSCSvS9Ze9BehVt4AaABAg', 'text': 'Congress tha lalluntop news latest people is desh ka bairagarh kar dai in jaise logo plz boycott karu', 'time': '8 days ago', 'author': '@user-ep5sv4jv4v', 'channel': 'UCNDSerP2jT62PZrD1ZO2YzA', 'votes': '0', 'replies': '', 'photo': 'https://yt3.ggpht.com/ytc/AIdro_k489dbUjVHiavMXCVBLGMHjuZ1MbGhFgMATRJyE25ZAk1KhQl3s6Hf7REnBDXFhbKjBA=s88-c-k-c0x00ffffff-no-rj', 'heart': False, 'reply': False, 'time_parsed': 1716262871.524228}
# ...

# %%
# !youtube-comment-downloader --url https://www.youtube.com/watch?v=2pB7bRjpwQc --output ll1.json --pretty
# Out:
# ...
# Downloaded 8504 comment(s)
# [207.56 seconds] Done!

# %% [markdown]
# - https://www.youtube.com/watch?v=2pB7bRjpwQc  Kerala Story
# - https://www.youtube.com/watch?v=30mUIWvVSxQ Banned China Apps
# - https://www.youtube.com/watch?v=ugx2V92YqBQ Love Jihad
# - https://www.youtube.com/watch?v=9kMlIdqwBPU CAA
# - https://www.youtube.com/watch?v=WsRAFHMaFy4 Delhi Riots 1
# - https://www.youtube.com/watch?v=r6vOR1VYuRQ&rco=1 Delhi Riots 2
# - https://www.youtube.com/watch?v=-bXiUDJY1vc Dalit
# - https://www.youtube.com/watch?v=GMjy06Cjflo IIT B SC/ST छात्रों से जातिगत भेदभाव
# - https://www.youtube.com/watch?v=68DwiOXcEp0 reservations in government jobs
# - https://www.youtube.com/watch?v=pp10RD6sq7Q Casteist teacher opposing Inter Caste Marriages
# - https://www.youtube.com/watch?v=jflC_EAJOlA
# - https://www.youtube.com/watch?v=dmPvE--FphU
# - https://www.youtube.com/watch?v=fnZooA8-Veg Manipur की Nurses Kolkata में Covid19
# - https://www.youtube.com/watch?v=M6nIZLuj1QQ
# - https://www.youtube.com/watch?v=pm37eOzE4ys
# - https://www.youtube.com/watch?v=6TMxG0XUPFg
# - https://www.youtube.com/shorts/D71s-yhY7QY
# - https://www.youtube.com/watch?v=H17yEj6mZeM
# - https://www.youtube.com/watch?v=9UeSrv0FUlc
# - https://www.youtube.com/watch?v=BbRGhF7ha6U
# - https://www.youtube.com/watch?v=PNjYLLBPwmo भीम कोरेगाव हिंसा
# - https://www.youtube.com/watch?v=zH3b0fN0JHk
# - https://www.youtube.com/watch?v=8skLD2wS8mE
# - https://www.youtube.com/watch?v=QumvM9DLMwk
# - https://www.youtube.com/watch?v=381cHIr_cAY
# - https://www.youtube.com/watch?v=4wxCXFm3oZA
# - https://www.youtube.com/watch?v=y622xHWC7JI
# - https://www.youtube.com/watch?v=70yLf97WPpk
# - https://www.youtube.com/watch?v=OJeU_242HaY
# - https://www.youtube.com/watch?v=S0K-WLaXHj4
# - https://www.youtube.com/watch?v=XkuoHsHC2TQ
# - https://www.youtube.com/watch?v=lIqneVWC2EM
# - https://www.youtube.com/watch?v=XkuoHsHC2TQ
# - https://www.youtube.com/watch?v=blCduVk5CUM
# - https://www.youtube.com/watch?v=SGoeiUHdoAc
# - https://www.youtube.com/watch?v=OO5Oo8fZ95E
# - https://www.youtube.com/watch?v=cCBdyUeF-SE
# - https://www.youtube.com/watch?v=4XGGY84Q9RA
# - https://www.youtube.com/watch?v=PKMhDe-NQfI
# - https://www.youtube.com/watch?v=3HzPU7r9LR8
# - https://www.youtube.com/watch?v=6oFoKX9VCQE

# %%
import subprocess

yt_list = ['https://www.youtube.com/watch?v=2pB7bRjpwQc',
           'https://www.youtube.com/watch?v=30mUIWvVSxQ',
           'https://www.youtube.com/watch?v=ugx2V92YqBQ',
           'https://www.youtube.com/watch?v=9kMlIdqwBPU'
           'https://www.youtube.com/watch?v=WsRAFHMaFy4',
           'https://www.youtube.com/watch?v=r6vOR1VYuRQ&rco=1',
           'https://www.youtube.com/watch?v=-bXiUDJY1vc',
           'https://www.youtube.com/watch?v=GMjy06Cjflo',
           'https://www.youtube.com/watch?v=68DwiOXcEp0',
           'https://www.youtube.com/watch?v=pp10RD6sq7Q',
           'https://www.youtube.com/watch?v=jflC_EAJOlA',
           'https://www.youtube.com/watch?v=dmPvE--FphU',
           'https://www.youtube.com/watch?v=fnZooA8-Veg',
           'https://www.youtube.com/watch?v=M6nIZLuj1QQ',
           'https://www.youtube.com/watch?v=pm37eOzE4ys',
           'https://www.youtube.com/watch?v=6TMxG0XUPFg',
           'https://www.youtube.com/shorts/D71s-yhY7QY',
           'https://www.youtube.com/watch?v=H17yEj6mZeM',
           'https://www.youtube.com/watch?v=9UeSrv0FUlc',
           'https://www.youtube.com/watch?v=BbRGhF7ha6U']

yt_list2 = ['https://www.youtube.com/watch?v=zH3b0fN0JHk',
            'https://www.youtube.com/watch?v=8skLD2wS8mE',
            'https://www.youtube.com/watch?v=QumvM9DLMwk',
            'https://www.youtube.com/watch?v=381cHIr_cAY',
            'https://www.youtube.com/watch?v=4wxCXFm3oZA',
            'https://www.youtube.com/watch?v=y622xHWC7JI',
            'https://www.youtube.com/watch?v=70yLf97WPpk',
            'https://www.youtube.com/watch?v=OJeU_242HaY',
            'https://www.youtube.com/watch?v=S0K-WLaXHj4',
            'https://www.youtube.com/watch?v=XkuoHsHC2TQ',
            'https://www.youtube.com/watch?v=lIqneVWC2EM',
            'https://www.youtube.com/watch?v=XkuoHsHC2TQ',
            'https://www.youtube.com/watch?v=blCduVk5CUM',
            'https://www.youtube.com/watch?v=SGoeiUHdoAc',
            'https://www.youtube.com/watch?v=OO5Oo8fZ95E',
            'https://www.youtube.com/watch?v=cCBdyUeF-SE',
            'https://www.youtube.com/watch?v=4XGGY84Q9RA',
            'https://www.youtube.com/watch?v=PKMhDe-NQfI',
            'https://www.youtube.com/watch?v=3HzPU7r9LR8',
            'https://www.youtube.com/watch?v=6oFoKX9VCQE']

for i,yt_link in enumerate(yt_list2):
  call = f"youtube-comment-downloader --url {yt_link} --output ll-2-{i}.json --pretty"
  call = call.split(' ')
  subprocess.call(call)

# %%
import os
import json
import pandas as pd

json_dir = '/content/drive/MyDrive/Thesis2'

all_comments = []

for file_name in os.listdir(json_dir):
    if file_name.endswith('.json'):
        file_path = os.path.join(json_dir, file_name)
        print(file_path)
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            for comment in data.get('comments', []):
              cid = comment.get('cid', '')
              author = comment.get('author', '')
              text = comment.get('text', '')
              replies = comment.get('replies', '')
              reply = comment.get('reply','')
              all_comments.append([cid, author, text, replies,reply])
# Out:
# /content/drive/MyDrive/Thesis2/ll2.json
# /content/drive/MyDrive/Thesis2/ll3.json
# /content/drive/MyDrive/Thesis2/ll4.json
# /content/drive/MyDrive/Thesis2/ll5.json
# /content/drive/MyDrive/Thesis2/ll0.json
# /content/drive/MyDrive/Thesis2/ll6.json
# /content/drive/MyDrive/Thesis2/ll7.json
# /content/drive/MyDrive/Thesis2/ll9.json
# /content/drive/MyDrive/Thesis2/ll10.json
# /content/drive/MyDrive/Thesis2/ll11.json
# /content/drive/MyDrive/Thesis2/ll12.json
# /content/drive/MyDrive/Thesis2/ll13.json
# /content/drive/MyDrive/Thesis2/ll14.json
# /content/drive/MyDrive/Thesis2/ll15.json
# /content/drive/MyDrive/Thesis2/ll16.json
# /content/drive/MyDrive/Thesis2/ll17.json
# /content/drive/MyDrive/Thesis2/ll18.json
# /content/drive/MyDrive/Thesis2/ll1.json
# /content/drive/MyDrive/Thesis2/ll-2-1.json
# /content/drive/MyDrive/Thesis2/ll-2-2.json
# /content/drive/MyDrive/Thesis2/ll-2-3.json
# /content/drive/MyDrive/Thesis2/ll-2-4.json
# /content/drive/MyDrive/Thesis2/ll-2-5.json
# ...

# %%
import csv

with open('output.csv', 'w', newline='', encoding='utf-8') as csv_file:
  writer = csv.writer(csv_file)
  # Write the header
  writer.writerow(['cid','author', 'text', 'replies','reply'])
  # Write the data
  writer.writerows(all_comments)

# %%
print(len(all_comments))
# Out:
# 210768

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=92ec754707c37eb8cb360dda44e7da073aa176e915da2f04796bf37020431ecf
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect_langs, DetectorFactory, detect

DetectorFactory.seed = 0
detect_langs("लेकिन जब साइन करने से पहले पता चल गया तो फिर वहां से लौट आना था, साइन क्यों किया? मूर्खता कहीं की!")
# Out:
# [hi:0.9999988086395474]

# %%
result = detect_langs("Jhooth bol rahi hai sab maloom tha")
print(result[0].prob,result[1].prob)
# Out:
# 0.857141011033115 0.14285743091360692

# %%
detect_langs("Same problem in Britain, france, germany. Hatts of france for banning burqa, muslim prophet.")
# Out:
# [en:0.9999958044620685]

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.ftz
# Out:
# --2024-05-29 05:04:43--  https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.ftz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 3.162.163.19, 3.162.163.11, 3.162.163.51, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|3.162.163.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 938013 (916K) [binary/octet-stream]
# Saving to: ‘lid.176.ftz’
#
# lid.176.ftz         100%[===================>] 916.03K  --.-KB/s    in 0.07s
#
# 2024-05-29 05:04:43 (12.6 MB/s) - ‘lid.176.ftz’ saved [938013/938013]

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 760.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227139 sha256=19da61721b1ecbca45cc66a3ed0f1d0f01899e51309a2040c958dd5eab400760
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
import fasttext
model = fasttext.load_model('lid.176.ftz')
print(model.predict('Jhooth bol rahi hai sab maloom tha', k=2))
# Out:
# (('__label__en', '__label__it'), array([0.18505663, 0.08339001]))
# ...

# %%
import pandas as pd
from tqdm import tqdm
from langdetect import detect_langs, DetectorFactory, detect, LangDetectException
from polyglot.detect import Detector

DetectorFactory.seed = 0
df = pd.read_csv('output.csv')

def predict_lang(text):
  try:
    # prediction = detect_langs(f'{text}')
    mixed_text = f"""{text}
    """
    print(mixed_text)
    prediction = Detector(mixed_text).languages
    if prediction:
        return [p.code for p in prediction],[p.confidence for p in prediction]
    else:
        return None, None

  except Exception as e:
        return None, None

# %%
print(predict_lang(df.iloc[9800].text))
# Out:
# I was know it will be interesting because I got 3 warning before video start 😂🤣
#
# (['en', 'un', 'un'], [98.0, 0.0, 0.0])

# %%
df
# Out:
#                                                       cid  \
# 0                              UgzX0MoRNPyKBHMFKlZ4AaABAg
# 1                              UgyDDW74lRRxJkDpvNh4AaABAg
# 2                              UgwIo9mY5q3laSiuwux4AaABAg
# 3                              UgwFYet6O60zqTtxqOB4AaABAg
# 4                              UgxAIgkJ8i5E5pSgNuR4AaABAg
# ...                                                   ...
# 217133  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njgfwa7bWW
# 217134  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njVwdQYMwB
# 217135  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njXhY1aBFd
# 217136  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbGYxKJng
# 217137  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbLmHnfoS
#
#                      author  \
# 0         @sushilkeshri4513
# 1         @sushilkeshri4513
# 2         @adartripathi6953
# 3          @kiranjadhav6832
# 4         @ajaypalsingh8205
# ...                     ...
# 217133  @amitrajchauhan1498
# 217134   @MANISHKUMAR-kj3pi
# ...

# %%
tqdm.pandas()
df['lang'], df['score'] = zip(*df['text'].progress_apply(predict_lang))

# %%
df.to_csv('output_w_lang.csv')

# %%
# !pip install polyglot PyICU pycld2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for PyICU: filename=PyICU-2.13.1-cp310-cp310-linux_x86_64.whl size=1801405 sha256=9c12445a7dfb766342124009e45667daa744d87cf01526353345a8757bfa0342
#   Stored in directory: /root/.cache/pip/wheels/8e/45/08/f4bc505e31eb7bb779d493226921abf18cf55ed30142e70eae
# ...
#   Created wheel for pycld2: filename=pycld2-0.41-cp310-cp310-linux_x86_64.whl size=9904032 sha256=41cc6114ec52466f52214b17efb9d22eb0f638923e3e9f004c842b026d7d55be
#   Stored in directory: /root/.cache/pip/wheels/be/81/31/240c89c845e008a93d98542325270007de595bfd356eb0b06c
# Successfully built PyICU pycld2
# ...

# %%
import pandas as pd

df1 = pd.read_csv('output_w_lang.csv')
# Out:
# <ipython-input-3-3ef3bbdd52ac>:3: DtypeWarning: Columns (0,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('output_w_lang.csv')

# %%
df1
# Out:
#        Unnamed: 0                                                cid  \
# 0               0                         UgzX0MoRNPyKBHMFKlZ4AaABAg
# 1               1                         UgyDDW74lRRxJkDpvNh4AaABAg
# 2               2                         UgwIo9mY5q3laSiuwux4AaABAg
# 3               3                         UgwFYet6O60zqTtxqOB4AaABAg
# 4               4                         UgxAIgkJ8i5E5pSgNuR4AaABAg
# ...           ...                                                ...
# 217134     217133  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njgfwa7bWW
# 217135     217134  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njVwdQYMwB
# 217136     217135  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njXhY1aBFd
# 217137     217136  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbGYxKJng
# 217138     217137  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbLmHnfoS
#
#                      author  \
# 0         @sushilkeshri4513
# 1         @sushilkeshri4513
# 2         @adartripathi6953
# ...

# %%
filtered_df = df1.drop(columns=['Unnamed: 0'])

# %%
type(filtered_df.iloc[9800].lang)
# Out:
# str

# %%
hin_filtered_df = filtered_df[filtered_df['lang'].apply(lambda x: 'hi' in x if isinstance(x, str) else False)]

# %%
hin_filtered_df
# Out:
#                                                       cid  \
# 4                              UgxAIgkJ8i5E5pSgNuR4AaABAg
# 23                             UgwI1FTnY2pRddhjUrR4AaABAg
# 24                             UgwBkYu85AkEftRuSmt4AaABAg
# 26                             UgwroPED0RcS-PcemsZ4AaABAg
# 31                             UgyWvnu8EC_ohr2eYvV4AaABAg
# ...                                                   ...
# 217094  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nn1Dri2u35
# 217105                         Ugy5eBJEz1Sr7xidGPd4AaABAg
# 217111  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8nj_z3pNLe-
# 217112  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8njbR4aXI6s
# 217128  Ugyx9iz2lHWdXz9tFl14AaABAg.8njTBmMY-hU8njbpXmeuve
#
#                         author  \
# 4            @ajaypalsingh8205
# 23       @shrikrishnasingh9035
# 24        @junaidbharatpur0062
# 26              @vrindadas2405
# 31                 @dpatel5210
# ...                        ...
# 217094          @alokranjan883
# ...

# %%
hinglish_filtered = filtered_df[~filtered_df['lang'].apply(lambda x: 'hi' in x if isinstance(x, str) else False)]

# %%
hin_filtered_df = hin_filtered_df[hin_filtered_df['text'].apply(count_words) > 5]
hinglish_filtered = hinglish_filtered[hinglish_filtered['text'].apply(count_words) > 5]

# %%
hin_filtered_df = hin_filtered_df[hin_filtered_df['text'].apply(count_words) <= 30]
hinglish_filtered = hinglish_filtered[hinglish_filtered['text'].apply(count_words) <= 30]

# %%
hin_filtered_df
# Out:
#                                                       cid  \
# 4                              UgxAIgkJ8i5E5pSgNuR4AaABAg
# 23                             UgwI1FTnY2pRddhjUrR4AaABAg
# 26                             UgwroPED0RcS-PcemsZ4AaABAg
# 38                             Ugx48S-Htsof0vOVJcR4AaABAg
# 39                             UgzTatYczGH0XuDortV4AaABAg
# ...                                                   ...
# 217094  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nn1Dri2u35
# 217105                         Ugy5eBJEz1Sr7xidGPd4AaABAg
# 217111  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8nj_z3pNLe-
# 217112  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8njbR4aXI6s
# 217128  Ugyx9iz2lHWdXz9tFl14AaABAg.8njTBmMY-hU8njbpXmeuve
#
#                         author  \
# 4            @ajaypalsingh8205
# 23       @shrikrishnasingh9035
# 26              @vrindadas2405
# 38               @Onlyyours963
# 39        @SurendraKumar-ce4qr
# ...                        ...
# 217094          @alokranjan883
# ...

# %%
hinglish_filtered
# Out:
#                                                       cid  \
# 2                              UgwIo9mY5q3laSiuwux4AaABAg
# 3                              UgwFYet6O60zqTtxqOB4AaABAg
# 5                              UgyWsWAWgtcNmUv1e4J4AaABAg
# 8                              UgyJtwi_bWqKz5_t33F4AaABAg
# 9                              UgyaQi-MtWkSHq4tzSV4AaABAg
# ...                                                   ...
# 217129  Ugwc2aTnCBsGYQuOq5x4AaABAg.8njT-IZ5hzh8njUTlSqNzF
# 217130  Ugy5eBJEz1Sr7xidGPd4AaABAg.8njSzVL1fa78njUab5GuRj
# 217132  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njWfT3_-oQ
# 217134  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njgfwa7bWW
# 217138  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbLmHnfoS
#
#                       author  \
# 2          @adartripathi6953
# 3           @kiranjadhav6832
# 5           @user-bz2hd4lr9b
# 8              @Marcus.22823
# 9       @THE_SANATANIST_ARYA
# ...                      ...
# 217129          @ANAND-cj1hv
# ...

# %%
hin_filtered_df = hin_filtered_df.drop_duplicates(subset='text')
hinglish_filtered = hinglish_filtered.drop_duplicates(subset='text')

# %%
hinglish_filtered
# Out:
#                                                       cid  \
# 2                              UgwIo9mY5q3laSiuwux4AaABAg
# 3                              UgwFYet6O60zqTtxqOB4AaABAg
# 5                              UgyWsWAWgtcNmUv1e4J4AaABAg
# 8                              UgyJtwi_bWqKz5_t33F4AaABAg
# 9                              UgyaQi-MtWkSHq4tzSV4AaABAg
# ...                                                   ...
# 217129  Ugwc2aTnCBsGYQuOq5x4AaABAg.8njT-IZ5hzh8njUTlSqNzF
# 217130  Ugy5eBJEz1Sr7xidGPd4AaABAg.8njSzVL1fa78njUab5GuRj
# 217132  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njWfT3_-oQ
# 217134  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njgfwa7bWW
# 217138  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbLmHnfoS
#
#                       author  \
# 2          @adartripathi6953
# 3           @kiranjadhav6832
# 5           @user-bz2hd4lr9b
# 8              @Marcus.22823
# 9       @THE_SANATANIST_ARYA
# ...                      ...
# 217129          @ANAND-cj1hv
# ...

# %%
hinglish_filtered.iloc[2].text
# Out:
# 'Jhooth bol rahi hai sab maloom tha'

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("token-classification", model="l3cube-pune/hing-bert-lid", device=0)

def detect_eng_in_hindi(text):
    result = pipe(text)
    is_english = all(list(j.values())[0] == 'EN' for j in result)
    return 1 if is_english else 0

# %%
hinglish_filtered.iloc[2].text
# Out:
# 'Jhooth bol rahi hai sab maloom tha'

# %%
r = pipe(hinglish_filtered.iloc[2].text)

# %%
detect_eng_in_hindi(hinglish_filtered.iloc[2].text)
# Out:
# 0

# %%
hinglish_filtered['is_english'] = hinglish_filtered['text'].apply(detect_eng_in_hindi)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# <ipython-input-29-fbd9f266c132>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hinglish_filtered['is_english'] = hinglish_filtered['text'].apply(detect_eng_in_hindi)

# %%
hinglish_filtered
# Out:
#                                                       cid  \
# 2                              UgwIo9mY5q3laSiuwux4AaABAg
# 3                              UgwFYet6O60zqTtxqOB4AaABAg
# 5                              UgyWsWAWgtcNmUv1e4J4AaABAg
# 8                              UgyJtwi_bWqKz5_t33F4AaABAg
# 9                              UgyaQi-MtWkSHq4tzSV4AaABAg
# ...                                                   ...
# 217129  Ugwc2aTnCBsGYQuOq5x4AaABAg.8njT-IZ5hzh8njUTlSqNzF
# 217130  Ugy5eBJEz1Sr7xidGPd4AaABAg.8njSzVL1fa78njUab5GuRj
# 217132  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njWfT3_-oQ
# 217134  UgzExUF_UHdx3fQzITN4AaABAg.8njSyx0zLdo8njgfwa7bWW
# 217138  UgzRIk0zg7d0xuyn8tl4AaABAg.8njSd2XjgDL8njbLmHnfoS
#
#                       author  \
# 2          @adartripathi6953
# 3           @kiranjadhav6832
# 5           @user-bz2hd4lr9b
# 8              @Marcus.22823
# 9       @THE_SANATANIST_ARYA
# ...                      ...
# 217129          @ANAND-cj1hv
# ...

# %%
hinglish_filtered = hinglish_filtered[hinglish_filtered['is_english'] != 1]

# %%
hinglish_filtered.to_csv("hinglish_filtered.csv", index=False, encoding='utf-8')

# %%
filtered_df.to_csv('filtered_output.csv', index=False, encoding='utf-8')

# %%
import pandas as pd

df2 = pd.read_csv('filtered_output_noduplicates.csv')

# %%
df2
# Out:
#                                                      cid  \
# 0                             UgxAIgkJ8i5E5pSgNuR4AaABAg
# 1                             UgwI1FTnY2pRddhjUrR4AaABAg
# 2                             UgwBkYu85AkEftRuSmt4AaABAg
# 3                             UgwroPED0RcS-PcemsZ4AaABAg
# 4                             UgyWvnu8EC_ohr2eYvV4AaABAg
# ...                                                  ...
# 26414  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nmlGh5v0jl
# 26415  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nmzCsCrQbI
# 26416  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nn1Dri2u35
# 26417  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8njbR4aXI6s
# 26418  Ugyx9iz2lHWdXz9tFl14AaABAg.8njTBmMY-hU8njbpXmeuve
#
#                       author  \
# 0          @ajaypalsingh8205
# 1      @shrikrishnasingh9035
# 2       @junaidbharatpur0062
# 3             @vrindadas2405
# 4                @dpatel5210
# ...                      ...
# 26414         @alokranjan883
# 26415              @AK-od5yd
# ...

# %%
df2 = df2.drop_duplicates(subset='text')

# %%
def count_words(text):
    return len(text.split())

# Filter rows where the text column has 3 or more words
# df2 = df2[df2['text'].apply(count_words) > 5]

# %%
count_words('हिंदू धर्म में जाति हिंदू धर्म में जाति व्यवस्था कैंसर बीमारीकी तरह है वीडियो में इस महिला ने भी कहा है कि राजपूत बाहर्मण जाति के लोग छोटी जाति को दूर से भगा देता है तो जाति व्यवस्था लोगों को तोड़ तोड़ कर रख दिया जाति व्यवस्था में जो अपने आप को ऊंची जाति के लोग वह गुंडागर्दी और आतंकवादी जैसा काम करता है')
# Out:
# 64

# %%
df2
# Out:
#                                                      cid  \
# 0                             UgxAIgkJ8i5E5pSgNuR4AaABAg
# 1                             UgwI1FTnY2pRddhjUrR4AaABAg
# 2                             UgwBkYu85AkEftRuSmt4AaABAg
# 3                             UgwroPED0RcS-PcemsZ4AaABAg
# 4                             UgyWvnu8EC_ohr2eYvV4AaABAg
# ...                                                  ...
# 26414  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nmlGh5v0jl
# 26415  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nmzCsCrQbI
# 26416  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nn1Dri2u35
# 26417  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8njbR4aXI6s
# 26418  Ugyx9iz2lHWdXz9tFl14AaABAg.8njTBmMY-hU8njbpXmeuve
#
#                       author  \
# 0          @ajaypalsingh8205
# 1      @shrikrishnasingh9035
# 2       @junaidbharatpur0062
# 3             @vrindadas2405
# 4                @dpatel5210
# ...                      ...
# 26414         @alokranjan883
# 26415              @AK-od5yd
# ...

# %%
df2 = df2[df2['text'].apply(count_words) <= 70]

# %%
df2
# Out:
#                                                      cid  \
# 0                             UgxAIgkJ8i5E5pSgNuR4AaABAg
# 1                             UgwI1FTnY2pRddhjUrR4AaABAg
# 2                             UgwBkYu85AkEftRuSmt4AaABAg
# 3                             UgwroPED0RcS-PcemsZ4AaABAg
# 5                             Ugx48S-Htsof0vOVJcR4AaABAg
# ...                                                  ...
# 26414  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nmlGh5v0jl
# 26415  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nmzCsCrQbI
# 26416  Ugw851RqskrGrQOrLgV4AaABAg.8njTfWdn_8T8nn1Dri2u35
# 26417  Ugx5znINiI13fRs5wUh4AaABAg.8njTHyQI_cK8njbR4aXI6s
# 26418  Ugyx9iz2lHWdXz9tFl14AaABAg.8njTBmMY-hU8njbpXmeuve
#
#                       author  \
# 0          @ajaypalsingh8205
# 1      @shrikrishnasingh9035
# 2       @junaidbharatpur0062
# 3             @vrindadas2405
# 5              @Onlyyours963
# ...                      ...
# 26414         @alokranjan883
# 26415              @AK-od5yd
# ...

# %%
df2.to_csv('filtered_output_noduplicates_v2.csv', index=False, encoding='utf-8')

# %%
code_mix_english = df2[df2['lang'].apply(lambda x: 'en' in x if isinstance(x, str) else False)]

# %%
code_mix_english.shape
# Out:
# (1990, 7)

# %%
code_mix_english.drop_duplicates(subset='text')
# Out:
#                                                      cid               author  \
# 4                             UgyWvnu8EC_ohr2eYvV4AaABAg          @dpatel5210
# 5                             Ugx48S-Htsof0vOVJcR4AaABAg        @Onlyyours963
# 8                             UgwmmPhHNS6eh1xgUrJ4AaABAg          @arjunr9958
# 32                            UgwrqeTzpRVc81rCExd4AaABAg           @rajur6267
# 35                            UgwJsFrcpMlV_-Vzj294AaABAg     @happysunday4262
# ...                                                  ...                  ...
# 39851                         UgzrgCZ_ofPqgZOaLDp4AaABAg      @harishkumar003
# 39897  Ugw9sSyF7WnkmkTCPt14AaABAg.8njY1rIWTms8nk4nXsZFge      @nitinnanda2471
# 39910                         UgxI25Zk7O64Nd8v4g14AaABAg  @swarndeepkumar4196
# 39918  UgxlxTE3r8P7vfGmppp4AaABAg.8njV4sshU-O8nk3m7wlztF          @Animeshuma
# 39919  UgxYfBGGb9SjMV0uA-h4AaABAg.8njUgV4LuE-8njbKwrv-15           @blive3302
#
# ...

# %%
df2 = df2.drop_duplicates(subset='text')

# %%
df2_filtered_only_hi = df2[~df2['lang'].apply(lambda x: 'en' in x if isinstance(x, str) else False)]

# %%
df2_filtered_only_hi = df2_filtered_only_hi.sample(n=4000)

# %%
merged_df = pd.concat([df2_filtered_only_hi, code_mix_english], ignore_index=True)

# %%
merged_df
# Out:
#                                                     cid  \
# 0                            Ugy3_dIDWrYS1vHV1vJ4AaABAg
# 1                            UgyA9Ht2KCagpUn5hfF4AaABAg
# 2                            UgyvbWDcaPz5FAxkT8h4AaABAg
# 3                            UgyZsVEQOexwHqKJp2J4AaABAg
# 4     UgyjdPQMBQPEzf5xr9l4AaABAg.9Eq7YLiNhlZ9Xj3y8K_Qxu
# ...                                                 ...
# 5985                         UgzrgCZ_ofPqgZOaLDp4AaABAg
# 5986  Ugw9sSyF7WnkmkTCPt14AaABAg.8njY1rIWTms8nk4nXsZFge
# 5987                         UgxI25Zk7O64Nd8v4g14AaABAg
# 5988  UgxlxTE3r8P7vfGmppp4AaABAg.8njV4sshU-O8nk3m7wlztF
# 5989  UgxYfBGGb9SjMV0uA-h4AaABAg.8njUgV4LuE-8njbKwrv-15
#
#                      author  \
# 0         @Goodwillgarments
# 1        @satyendrasingh147
# 2              @rakjarnikar
# 3            @ramjanali3662
# 4     @ShailendraSinghRatre
# ...                     ...
# 5985        @harishkumar003
# 5986        @nitinnanda2471
# ...

# %%
merged_df.to_csv('filtered_final_output11.csv', index=False, encoding='utf-8')

# %%
import pandas as pd
df4 = pd.read_csv('filtered_output_noduplicates_v2.csv')

# %%
enll = df4[df4['lang'].apply(lambda x: 'en' in x if isinstance(x, str) else False)]

# %%
enll.to_csv('enll11.csv', index=False, encoding='utf-8')
